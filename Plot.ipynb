# %%
# %matplotlib inline
import pandas as pd
from IPython.core.display import HTML
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
car = pd.DataFrame.from_csv('carstats.csv', index_col=None)
fig1 = car[['evttime','car']]

# %%
fig1 = fig1.rename(columns={'evttime': 'Days Relative to Settlement Date 0', 'car': 'Cumulative Abnormal Return'})

# %%
fig1
# Out:
#     Days Relative to Settlement Date 0  Cumulative Abnormal Return
# 0                                   -7                    0.002683
# 1                                   -6                    0.007526
# 2                                   -5                    0.005407
# 3                                   -4                    0.003834
# 4                                   -3                    0.002925
# 5                                   -2                    0.003390
# 6                                   -1                    0.005936
# 7                                    0                    0.006177
# 8                                    1                    0.004866
# 9                                    2                    0.006999
# 10                                   3                    0.007766
# 11                                   4                    0.006416
# 12                                   5                    0.009895
# ...

# %%
sns.set_style("whitegrid")
f1 = sns.barplot(x = "Days Relative to Settlement Date 0", y="Cumulative Abnormal Return", data=fig1, palette="Blues_d")
f1.figure.savefig("fig1.pdf", format='pdf', dpi=800)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'tic', 'Settle_date', 'cret_1', 'car_1', 'bhar_1',
#        'cret_5', 'car_5', 'bhar_5', 'cret_15', 'car_15', 'bhar_15', 'cret_30',
#        'car_30', 'bhar_30', 'cret_60', 'car_60', 'bhar_60', 'cret_180',
#        'car_180', 'bhar_180', 'ceyr', 'styr', 'seta_sum', 'GC_opinion_sum',
#        'Class_end', 'gap', 'sic_x', 'lgap', 'gvkey', 'date', 'fyear', 'at',
#        'ceql', 'csho', 'ebit_st', 'epsfi', 'epsfx', 'sale', 'seta', 'xsga',
#        'sic_y', 'GC_opinion', 'ebit_ce', 'at_log', 'ceql_log', 'News_ST',
#        'News_CE', 'News_Winner_ST', 'News_Winner_CE'],
#       dtype='object')

# %%
fig3 = df[['News_Winner_ST','car_15']]
#fig3 = fig3.rename(columns={ })
sns.set(style="darkgrid", color_codes=True)

# %%
sns.distplot(df.car_15)

# %%
fig3 = fig3.rename(columns={'car_15':'15 Days Cummlative Abnormal Return'})

# %%
g = sns.FacetGrid(fig3, col="News_Winner_ST", col_order=[1, 0])
g = g.map(sns.kdeplot, '15 Days Cummlative Abnormal Return')
g.savefig("fig3.pdf", format='pdf', dpi=800)

# %%
f4 = sns.jointplot(x="Settle Period", y="Firm Size", data=fig1, kind="kde");
f4.plot_joint(plt.scatter, c="g", s=30, linewidth=1, marker="+")
f4.ax_joint.collections[0].set_alpha(0)
f4.set_axis_labels("$Settle Period$", "$Firm Size$");
f4.savefig("fig1.pdf", format='pdf', dpi=800)

# %%
fig = plt.figure()
ax = plt.figure().gca(projection='3d')
ax.scatter(x,y,z)
ax.set_xlabel('Settlement Period')
ax.set_ylabel('Firm Size')
ax.set_zlabel('Abnormal Return')
plt.savefig('myfig.eps', 
plt.show()
